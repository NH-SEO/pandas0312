# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

# %% [markdown]
# # Apply, Map

# %% [markdown]
# # 56

# %%
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/BankChurnersUp.csv',index_col=0)
df.shape
# Out:
# (10127, 18)

# %% [markdown]
# # 57

# %%
income_map = {
    'Unknown' : 'N',
    'Less than $40K' : 'a',
    '$40K - $60K' : 'b',
    '$60K - $80K' : 'c',
    '$80K - $120K' : 'd',
    '$120K +’' : 'e'
}

df['newIncome'] = df['Income_Category'].map(income_map)

# %% [markdown]
# # 58

# %%
def get_category(x):
    if x =='Unknown':
        return 'N'
    elif x =='Less than $40K':
        return 'a'
    elif x =='$40K - $60K':   
        return 'b'
    elif x =='$60K - $80K':    
        return 'c'
    elif x =='$80K - $120K':   
        return 'd'
    elif x =='$120K +' :     
        return 'e'
    
df['newIncome'] = df['Income_Category'].apply(get_category)

# %% [markdown]
# # 59

# %%
df['AgeState'] = df['Customer_Age'].map(lambda x: x//10 * 10)

# %%
df['AgeState'].value_counts().sort_index()
# Out:
# 20     195
# 30    1841
# 40    4561
# 50    2998
# 60     530
# 70       2
# Name: AgeState, dtype: int64

# %% [markdown]
# # 60

# %%
df['newEduLevel'] = \
    df['Education_Level'].map(lambda x: 1 if 'Graduate' in x else 0)

# %%
df['newEduLevel'].value_counts()
# Out:
# 0    6483
# 1    3644
# Name: newEduLevel, dtype: int64

# %%
df['newEduLevel'] = \
    np.where(df['Education_Level'].str.contains('Graduate'),
             1,
             0)

# %%
df['newEduLevel'].value_countsts()
# Out:
# 0    6483
# 1    3644
# Name: newEduLevel, dtype: int64

# %% [markdown]
# # 61

# %%
df['newLimit'] = df['Credit_Limit'].map(lambda x: 1 if x>=4500 else 0)

# %%
df['newLimit'].value_counts()
# Out:
# 1    5096
# 0    5031
# Name: newLimit, dtype: int64

# %% [markdown]
# # 62

# %%
df['newState'] =\
    df.apply(lambda x: \
             1 if (x['Marital_Status'] == 'Married') and (x['Card_Category'] == 'Platinum') else 0,\
             axis=1)

# %%
df['newState'].value_counts()
# Out:
# 0    10120
# 1        7
# Name: newState, dtype: int64

# %%
def get_new_state(row):
    if row['Marital_Status'] == 'Married' and row['Card_Category'] == 'Platinum':
        return 1
    else:
        return 0
    
df.apply(get_new_state, axis=1).value_counts()
# Out:
# 0    10120
# 1        7
# dtype: int64

# %%
df['newState'] = \
    np.where((df['Marital_Status'] == 'Married') & (df['Card_Category'] == 'Platinum'),\
           1,
           0)

# %%
df['newState'].value_counts()
# Out:
# 0    10120
# 1        7
# Name: newState, dtype: int64

# %% [markdown]
# # 63

# %%
df['Gender'] = df['Gender'].map(lambda x: 'male' if x == 'M' else 'female')

# %%
df['Gender'].value_counts()
# Out:
# female    5358
# male      4769
# Name: Gender, dtype: int64

# %% [markdown]
# # Time_Series

# %% [markdown]
# # 64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/timeTest.csv')
df.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# # 65

# %%
df['Yr_Mo_Dy'] = pd.to_datetime(df['Yr_Mo_Dy'])

# %% [markdown]
# # 66

# %%
df['Yr_Mo_Dy'].dt.year.unique()
# Out:
# array([2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978], dtype=int64)

# %% [markdown]
# # 67

# %%
def fix_date(x):
    year = x.year
    month = x.month
    day = x.day
    
    if year >= 2061:
        year = year - 100
        
    return f'{year}-{month}-{day}'
    
df['Yr_Mo_Dy'] = pd.to_datetime(df['Yr_Mo_Dy'].map(fix_date))

# %%
df['Yr_Mo_Dy']
# Out:
# 0      1961-01-01
# 1      1961-01-02
# 2      1961-01-03
# 3      1961-01-04
# 4      1961-01-05
#           ...
# 6569   1978-12-27
# 6570   1978-12-28
# 6571   1978-12-29
# 6572   1978-12-30
# 6573   1978-12-31
# Name: Yr_Mo_Dy, Length: 6574, dtype: datetime64[ns]

# %% [markdown]
# # 68

# %%
df['year'] = df['Yr_Mo_Dy'].dt.year

# %%
df.groupby('year').mean()
# Out:
#             RPT        VAL        ROS       KIL        SHA       BIR  \
# year
# 1961  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972  12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %% [markdown]
# # 69

# %%
df['weekday'] = df['Yr_Mo_Dy'].dt.weekday

# %% [markdown]
# # 70

# %%
df['WeekCheck'] = np.where(df['weekday'].isin([5, 6]), 1, 0)

# %%
df['WeekCheck'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: WeekCheck, dtype: int32

# %% [markdown]
# # 71

# %%
df['month'] = df['Yr_Mo_Dy'].dt.month

# %%
df.groupby('month').mean()
# Out:
#              RPT        VAL        ROS       KIL        SHA       BIR  \
# month
# 1      14.847325  12.914560  13.299624  7.199498  11.667734  8.054839
# 2      13.710906  12.111122  12.879132  6.942411  11.551772  7.633858
# 3      13.158687  11.505842  12.648118  7.265907  11.554516  7.959409
# 4      12.555648  10.429759  12.204815  6.898037  10.677667  7.441389
# 5      11.724032  10.145619  11.550394  6.307487  10.224301  6.942061
# 6      10.451317   8.949704  10.361315  5.652278   9.529926  6.410093
# 7       9.992007   8.357778   9.349642  5.416935   9.302634  5.972348
# 8      10.213411   8.415143   9.993441  5.270681   8.901559  5.891057
# 9      11.458519   9.981002  10.756883  5.615176   9.766315  6.566222
# 10     12.660610  11.010681  11.453943  6.065215  10.550251  7.159910
# 11     13.200722  11.639500  12.293407  6.247611  10.501130  7.134333
# 12     14.446398  12.353602  13.212276  6.829910  11.301254  7.963710
#
# ...

# %% [markdown]
# # 72

# %%
df.isna().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          6
# VAL          3
# ROS          2
# KIL          5
# SHA          2
# BIR          0
# DUB          3
# CLA          2
# MUL          3
# CLO          1
# BEL          0
# MAL          4
# year         0
# weekday      0
# WeekCheck    0
# month        0
# dtype: int64

# %%
df = df.fillna(method='ffill')
df.isna().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          0
# VAL          0
# ROS          0
# KIL          0
# SHA          1
# BIR          0
# DUB          0
# CLA          0
# MUL          0
# CLO          0
# BEL          0
# MAL          0
# year         0
# weekday      0
# WeekCheck    0
# month        0
# dtype: int64

# %%
df.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71  14.96  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25  10.04   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL  year  weekday  WeekCheck  month
# 0  12.58  18.50  15.04  1961        6          1      1
# 1   9.67  17.54  13.83  1961        0          0      1
# 2   7.67  12.75  12.71  1961        1          0      1
# 3   5.88   5.46  10.88  1961        2          0      1
# 4  10.34  12.92  11.83  1961        3          0      1

# %%
df = df.fillna(method='bfill')

# %%
df.isna().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          0
# VAL          0
# ROS          0
# KIL          0
# SHA          0
# BIR          0
# DUB          0
# CLA          0
# MUL          0
# CLO          0
# BEL          0
# MAL          0
# year         0
# weekday      0
# WeekCheck    0
# month        0
# dtype: int64

# %% [markdown]
# # 73

# %%
df.groupby(['year', 'month']).mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# year month
# 1961 1      14.932581  12.084194  13.431613  7.736774  11.215806   8.588065
#      2      16.269286  14.975357  14.324643  9.116786  13.852143  10.937500
#      3      11.015806  11.296452  10.752903  7.137742  10.509355   8.866774
#      4      10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
#      5       9.860968   8.735161  10.818065  5.892258   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 2070 8       9.561613   8.389677   9.485161  4.765806   8.016774   5.660323
#      9      11.926667  12.082333  11.035333  6.509333  11.482000   7.693000
#      10     13.354839  11.937097  11.378710  6.665806  11.728387   8.450000
#      11     13.721667  11.998333  12.118667  6.504000  10.861000   8.169333
#      12     12.788710   9.659032  14.111935  5.684516  10.013548   6.186129
#
# ...

# %% [markdown]
# # diff, shift

# %%
df = pd.DataFrame({'a': [1, 2, 3, 4, 5], 'b': [4, 5, 6, 7, 8], 'c': [10, 20, 30, 40, 50]})
df
# Out:
#    a  b   c
# 0  1  4  10
# 1  2  5  20
# 2  3  6  30
# 3  4  7  40
# 4  5  8  50

# %%
df.diff(periods=2, axis=0)
# Out:
#      a    b     c
# 0  NaN  NaN   NaN
# 1  NaN  NaN   NaN
# 2  2.0  2.0  20.0
# 3  2.0  2.0  20.0
# 4  2.0  2.0  20.0

# %%
df['a'].shift(1)
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3    3.0
# 4    4.0
# Name: a, dtype: float64

# %% [markdown]
# # 75

# %%
df[['a', 'b']].rolling(3).sum()
# Out:
#       a     b
# 0   NaN   NaN
# 1   NaN   NaN
# 2   6.0  15.0
# 3   9.0  18.0
# 4  12.0  21.0

# %% [markdown]
# # Grouping
